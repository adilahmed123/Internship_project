# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import requests
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome("E:\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.yatra.com/')

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=23%2F03%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=193853671637'
driver.get(url)

# %%
Company_Name = []
jt = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt:
    j =data.text
    Company_Name.append(j)
Company_Name

# %%
len(Company_Name)

# %%
Flight_Name = []
fn = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn:
    f = data.text
    Flight_Name.append(f)
Flight_Name

# %%
Arrival = []
ar = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar:
    a = data.text
    Arrival.append(a)
Arrival

# %%
Departure = []
dr = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr:
    d = data.text.split('\n')[2]
    Departure.append(d)
Departure

# %%
Source = []
sr = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr:
    s = data.text.split('\n')[1]
    Source.append(s)
Source

# %%
Destination = []
dn = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn:
    ds = data.text.split('\n')[-1]
    Destination.append(ds)
Destination

# %%
Duration = []
dr = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr:
    d = data.text
    Duration.append(d)
Duration

# %%
Stops = []
st = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st:
    s = data.text.split('\n')[1]
    Stops.append(s)
Stops

# %%
Meals = []
ms = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms:
    m = data.text
    Meals.append(m)
Meals

# %%
len(Meals)

# %%
Price = []
pr = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr:
    p = data.text
    Price.append(p)
Price

# %%
yt = {'Company_Name': Company_Name,'Flight_Name':Flight_Name,'Arrival':Arrival,'Departure':Departure,'Source':Source,'Destination':Destination,'Duration':Duration,'Stops': Stops,'Meals_Avilablity':Meals,'Price':Price}
df1 = pd.DataFrame.from_dict(yt,orient = 'index')
df1 = df1.transpose()
df1

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1177705634423&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name1 = []
jt1 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt1:
    j1 =data.text
    Company_Name1.append(j1)
Company_Name1

# %%
Flight_Name1 = []
fn1 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn1:
    f1 = data.text
    Flight_Name1.append(f1)
Flight_Name1

# %%
Arrival1 = []
ar1 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar1:
    a1 = data.text
    Arrival1.append(a1)
Arrival1

# %%
Departure1 = []
dr1 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr1:
    d1 = data.text.split('\n')[2]
    Departure1.append(d1)
Departure1

# %%
Source1 = []
sr1 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr1:
    s1 = data.text.split('\n')[1]
    Source1.append(s1)
Source1

# %%
Destination1 = []
dn1 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn1:
    ds1 = data.text.split('\n')[-1]
    Destination1.append(ds1)
Destination1

# %%
Duration1 = []
dr1 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr1:
    d1 = data.text
    Duration1.append(d1)
Duration1

# %%
Stops1 = []
st1 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st1:
    s1 = data.text.split('\n')[1]
    Stops1.append(s1)
Stops1

# %%
Meals1 = []
ms1 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms1:
    m1 = data.text
    Meals1.append(m1)
Meals1

# %%
Price1 = []
pr1 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr1:
    p1 = data.text
    Price1.append(p1)
Price1

# %%
yt1 = {'Company_Name': Company_Name1,'Flight_Name':Flight_Name1,'Arrival':Arrival1,'Departure':Departure1,'Source':Source1,'Destination':Destination1,'Duration':Duration1,'Stops': Stops1,'Meals_Avilablity':Meals1,'Price':Price1}
df2 = pd.DataFrame.from_dict(yt1,orient = 'index')
df2 = df2.transpose()
df2

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=1501235578689&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name2 = []
jt2 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt2:
    j2 =data.text
    Company_Name2.append(j2)
Company_Name2

# %%
Flight_Name2 = []
fn2 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn2:
    f2 = data.text
    Flight_Name2.append(f2)
Flight_Name2

# %%
Arrival2 = []
ar2 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar2:
    a2 = data.text
    Arrival2.append(a2)
Arrival2

# %%
Departure2 = []
dr2 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr2:
    d2 = data.text.split('\n')[2]
    Departure2.append(d2)
Departure2

# %%
Source2 = []
sr2 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr2:
    s2 = data.text.split('\n')[1]
    Source2.append(s2)
Source2

# %%
Destination2 = []
dn2 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn2:
    ds2 = data.text.split('\n')[-1]
    Destination2.append(ds2)
Destination2

# %%
Duration2 = []
dr2 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr2:
    d2 = data.text
    Duration2.append(d2)
Duration2

# %%
Stops2 = []
st2 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st2:
    s2 = data.text.split('\n')[1]
    Stops2.append(s2)
Stops2

# %%
Meals2 = []
ms2 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms2:
    m2 = data.text
    Meals2.append(m2)
Meals2

# %%
Price2 = []
pr2 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr2:
    p2 = data.text
    Price2.append(p2)
Price2

# %%
yt2 = {'Company_Name': Company_Name2,'Flight_Name':Flight_Name2,'Arrival':Arrival2,'Departure':Departure2,'Source':Source2,'Destination':Destination2,'Duration':Duration2,'Stops': Stops2,'Meals_Avilablity':Meals2,'Price':Price2}
df3 = pd.DataFrame.from_dict(yt2,orient = 'index')
df3 = df3.transpose()
df3

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=23%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=169249450326&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name3 = []
jt3 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt3:
    j3 =data.text
    Company_Name3.append(j3)
Company_Name3

# %%
Flight_Name3 = []
fn3 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn3:
    f3 = data.text
    Flight_Name3.append(f3)
Flight_Name3

# %%
Arrival3 = []
ar3 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar3:
    a3 = data.text
    Arrival3.append(a3)
Arrival3

# %%
Departure3 = []
dr3 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr3:
    d3 = data.text.split('\n')[2]
    Departure3.append(d3)
Departure3

# %%
Source3 = []
sr3 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr3:
    s3 = data.text.split('\n')[1]
    Source3.append(s3)
Source3

# %%
Destination3 = []
dn3 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn3:
    ds3 = data.text.split('\n')[-1]
    Destination3.append(ds3)
Destination3

# %%
Duration3 = []
dr3 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr3:
    d3 = data.text
    Duration3.append(d3)
Duration3

# %%
Stops3 = []
st3 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st3:
    s3 = data.text.split('\n')[1]
    Stops3.append(s3)
Stops3

# %%
Meals3 = []
ms3 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms3:
    m3 = data.text
    Meals3.append(m3)
Meals3

# %%
Price3 = []
pr3 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr3:
    p3 = data.text
    Price3.append(p3)
Price3

# %%
yt3 = {'Company_Name': Company_Name3,'Flight_Name':Flight_Name3,'Arrival':Arrival3,'Departure':Departure3,'Source':Source3,'Destination':Destination3,'Duration':Duration3,'Stops': Stops3,'Meals_Avilablity':Meals3,'Price':Price3}
df4 = pd.DataFrame.from_dict(yt3,orient = 'index')
df4 = df4.transpose()
df4

# %%
df = pd.concat([df1,df2,df3,df4])
df

# %%
df.to_csv("E:\Data set\Flightprice1.csv")

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=24%2F03%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=1595831431122&version=1.3&viewName=normal'
driver.get(url)

# %%
Company_Name4 = []
jt4 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt4:
    j4 =data.text
    Company_Name4.append(j4)
Company_Name4

# %%
Flight_Name4 = []
fn4 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn4:
    f4 = data.text
    Flight_Name4.append(f4)
Flight_Name4

# %%
Arrival4 = []
ar4 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar4:
    a4 = data.text
    Arrival4.append(a4)
Arrival4

# %%
Departure4 = []
dr4 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr4:
    d4 = data.text.split('\n')[2]
    Departure4.append(d4)
Departure4

# %%
Source4 = []
sr4 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr4:
    s4 = data.text.split('\n')[1]
    Source4.append(s4)
Source4

# %%
Destination4 = []
dn4 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn4:
    ds4 = data.text.split('\n')[-1]
    Destination4.append(ds4)
Destination4

# %%
Duration4 = []
dr4 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr4:
    d4 = data.text
    Duration4.append(d4)
Duration4

# %%
Stops4 = []
st4 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st4:
    s4 = data.text.split('\n')[1]
    Stops4.append(s4)
Stops4

# %%
Meals4 = []
ms4 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms4:
    m4 = data.text
    Meals4.append(m4)
Meals4

# %%
Price4 = []
pr4 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr4:
    p4 = data.text
    Price4.append(p4)
Price4

# %%
yt4 = {'Company_Name': Company_Name4,'Flight_Name':Flight_Name4,'Arrival':Arrival4,'Departure':Departure4,'Source':Source4,'Destination':Destination4,'Duration':Duration4,'Stops': Stops4,'Meals_Avilablity':Meals4,'Price':Price4}
df5 = pd.DataFrame.from_dict(yt4,orient = 'index')
df5 = df5.transpose()
df5

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=24%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1311164727689&version=1.3&viewName=normal'
driver.get(url)

# %%
Company_Name5 = []
jt5 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt5:
    j5 =data.text
    Company_Name5.append(j5)
Company_Name5

# %%
Flight_Name5 = []
fn5 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn5:
    f5 = data.text
    Flight_Name5.append(f5)
Flight_Name5

# %%
Arrival5 = []
ar5 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar5:
    a5 = data.text
    Arrival5.append(a5)
Arrival5

# %%
Departure5 = []
dr5 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr5:
    d5 = data.text.split('\n')[2]
    Departure5.append(d5)
Departure5

# %%
Source5 = []
sr5 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr5:
    s5 = data.text.split('\n')[1]
    Source5.append(s5)
Source5

# %%
Destination5 = []
dn5 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn5:
    ds5 = data.text.split('\n')[-1]
    Destination5.append(ds5)
Destination5

# %%
Duration5 = []
dr5 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr5:
    d5 = data.text
    Duration5.append(d5)
Duration5

# %%
Stops5 = []
st5 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st5:
    s5 = data.text.split('\n')[1]
    Stops5.append(s5)
Stops5

# %%
Meals5 = []
ms5 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms5:
    m5 = data.text
    Meals5.append(m5)
Meals5

# %%
Price5 = []
pr5 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr5:
    p5 = data.text
    Price5.append(p5)
Price5

# %%
yt5 = {'Company_Name': Company_Name5,'Flight_Name':Flight_Name5,'Arrival':Arrival5,'Departure':Departure5,'Source':Source5,'Destination':Destination5,'Duration':Duration5,'Stops': Stops5,'Meals_Avilablity':Meals5,'Price':Price5}
df6 = pd.DataFrame.from_dict(yt5,orient = 'index')
df6 = df6.transpose()
df6

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=24%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1512449233896&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name6 = []
jt6 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt6:
    j6 =data.text
    Company_Name6.append(j6)
Company_Name6

# %%
Flight_Name6 = []
fn6 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn6:
    f6 = data.text
    Flight_Name6.append(f6)
Flight_Name6

# %%
Arrival6 = []
ar6 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar6:
    a6 = data.text
    Arrival6.append(a6)
Arrival6

# %%
Departure6 = []
dr6 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr6:
    d6 = data.text.split('\n')[2]
    Departure6.append(d6)
Departure6

# %%
Source6 = []
sr6 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr6:
    s6 = data.text.split('\n')[1]
    Source6.append(s6)
Source6

# %%
Destination6 = []
dn6 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn6:
    ds6 = data.text.split('\n')[-1]
    Destination6.append(ds6)
Destination6

# %%
Duration6 = []
dr6 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr6:
    d6 = data.text
    Duration6.append(d6)
Duration6

# %%
Stops6 = []
st6 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st6:
    s6 = data.text.split('\n')[1]
    Stops6.append(s6)
Stops6

# %%
Meals6 = []
ms6 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms6:
    m6 = data.text
    Meals6.append(m6)
Meals6

# %%
Price6 = []
pr6 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr6:
    p6 = data.text
    Price6.append(p6)
Price6

# %%
yt6 = {'Company_Name': Company_Name6,'Flight_Name':Flight_Name6,'Arrival':Arrival6,'Departure':Departure6,'Source':Source6,'Destination':Destination6,'Duration':Duration6,'Stops': Stops6,'Meals_Avilablity':Meals6,'Price':Price6}
df7 = pd.DataFrame.from_dict(yt6,orient = 'index')
df7 = df7.transpose()
df7

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=24%2F03%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=527412757730&version=1.3&viewName=normal'
driver.get(url)

# %%
Company_Name7 = []
jt7 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt7:
    j7 =data.text
    Company_Name7.append(j7)
Company_Name7

# %%
Flight_Name7 = []
fn7 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn7:
    f7 = data.text
    Flight_Name7.append(f7)
Flight_Name7

# %%
Arrival7 = []
ar7 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar7:
    a7 = data.text
    Arrival7.append(a7)
Arrival7

# %%
Departure7 = []
dr7 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr7:
    d7 = data.text.split('\n')[2]
    Departure7.append(d7)
Departure7

# %%
Source7 = []
sr7 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr7:
    s7 = data.text.split('\n')[1]
    Source7.append(s7)
Source7

# %%
Destination7 = []
dn7 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn7:
    ds7 = data.text.split('\n')[-1]
    Destination7.append(ds7)
Destination7

# %%
Duration7 = []
dr7 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr7:
    d7 = data.text
    Duration7.append(d7)
Duration7

# %%
Stops7 = []
st7 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st7:
    s7 = data.text.split('\n')[1]
    Stops7.append(s7)
Stops7

# %%
Meals7 = []
ms7 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms7:
    m7 = data.text
    Meals7.append(m7)
Meals7

# %%
Price7 = []
pr7 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr7:
    p7 = data.text
    Price7.append(p7)
Price7

# %%
yt7 = {'Company_Name': Company_Name7,'Flight_Name':Flight_Name7,'Arrival':Arrival7,'Departure':Departure7,'Source':Source7,'Destination':Destination7,'Duration':Duration7,'Stops': Stops7,'Meals_Avilablity':Meals7,'Price':Price7}
df8 = pd.DataFrame.from_dict(yt7,orient = 'index')
df8 = df8.transpose()
df8

# %%
d = pd.concat([df5,df6,df7,df8])
d

# %%
d.to_csv("E:\Data set\Flightprice2.csv")

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=IDR&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=175977018756&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name8 = []
jt8 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt8:
    j8 =data.text
    Company_Name8.append(j8)
Company_Name8

# %%
Flight_Name8 = []
fn8 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn8:
    f8 = data.text
    Flight_Name8.append(f8)
Flight_Name8

# %%
Arrival8 = []
ar8 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar8:
    a8 = data.text
    Arrival8.append(a8)
Arrival8

# %%
Departure8 = []
dr8 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr8:
    d8 = data.text.split('\n')[2]
    Departure8.append(d8)
Departure8

# %%
Source8 = []
sr8 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr8:
    s8 = data.text.split('\n')[1]
    Source8.append(s8)
Source8

# %%
Destination8 = []
dn8 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn8:
    ds8 = data.text.split('\n')[-1]
    Destination8.append(ds8)
Destination8

# %%
Duration8 = []
dr8 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr8:
    d8 = data.text
    Duration8.append(d8)
Duration8

# %%
Stops8 = []
st8 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st8:
    s8 = data.text.split('\n')[1]
    Stops8.append(s8)
Stops8

# %%
Meals8 = []
ms8 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms8:
    m8 = data.text
    Meals8.append(m8)
Meals8

# %%
Price8 = []
pr8 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr8:
    p8 = data.text
    Price8.append(p8)
Price8

# %%
yt8 = {'Company_Name': Company_Name8,'Flight_Name':Flight_Name8,'Arrival':Arrival8,'Departure':Departure8,'Source':Source8,'Destination':Destination8,'Duration':Duration8,'Stops': Stops8,'Meals_Avilablity':Meals8,'Price':Price8}
df9 = pd.DataFrame.from_dict(yt8,orient = 'index')
df9 = df9.transpose()
df9

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=IDR&originCountry=IN&type=O&unique=1587204204540&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name9 = []
jt9 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt9:
    j9 =data.text
    Company_Name9.append(j9)
Company_Name9

# %%
Flight_Name9 = []
fn9 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn9:
    f9 = data.text
    Flight_Name9.append(f9)
Flight_Name9

# %%
Arrival9 = []
ar9 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar9:
    a9 = data.text
    Arrival9.append(a9)
Arrival9

# %%
Departure9 = []
dr9 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr9:
    d9 = data.text.split('\n')[2]
    Departure9.append(d9)
Departure9

# %%
Source9 = []
sr9 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr9:
    s9 = data.text.split('\n')[1]
    Source9.append(s9)
Source9

# %%
Destination9 = []
dn9 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn9:
    ds9 = data.text.split('\n')[-1]
    Destination9.append(ds9)
Destination9

# %%
Duration9 = []
dr9 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr9:
    d9 = data.text
    Duration9.append(d9)
Duration9

# %%
Stops9 = []
st9 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st9:
    s9 = data.text.split('\n')[1]
    Stops9.append(s9)
Stops9

# %%
Meals9 = []
ms9 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms9:
    m9 = data.text
    Meals9.append(m9)
Meals9

# %%
Price9 = []
pr9 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr9:
    p9 = data.text
    Price9.append(p9)
Price9

# %%
yt9 = {'Company_Name': Company_Name9,'Flight_Name':Flight_Name9,'Arrival':Arrival9,'Departure':Departure9,'Source':Source9,'Destination':Destination9,'Duration':Duration9,'Stops': Stops9,'Meals_Avilablity':Meals9,'Price':Price9}
df10 = pd.DataFrame.from_dict(yt8,orient = 'index')
df10 = df10.transpose()
df10

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=948282890912&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name10 = []
jt10 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt10:
    j10 =data.text
    Company_Name10.append(j10)
Company_Name10

# %%
Flight_Name10 = []
fn10 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn10:
    f10 = data.text
    Flight_Name10.append(f10)
Flight_Name10

# %%
Arrival10 = []
ar10 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar10:
    a10 = data.text
    Arrival10.append(a10)
Arrival10

# %%
Departure10 = []
dr10 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr10:
    d10 = data.text.split('\n')[2]
    Departure10.append(d10)
Departure10

# %%
Source10 = []
sr10 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr10:
    s10 = data.text.split('\n')[1]
    Source10.append(s10)
Source10

# %%
Destination10 = []
dn10 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn10:
    ds10 = data.text.split('\n')[-1]
    Destination10.append(ds10)
Destination10

# %%
Duration10 = []
dr10 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr10:
    d10 = data.text
    Duration10.append(d10)
Duration10

# %%
Stops10 = []
st10 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st10:
    s10 = data.text.split('\n')[1]
    Stops10.append(s10)
Stops10

# %%
Meals10 = []
ms10 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms10:
    m10 = data.text
    Meals10.append(m10)
Meals10

# %%
Price10 = []
pr10 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr10:
    p10 = data.text
    Price10.append(p10)
Price10

# %%
yt10 = {'Company_Name': Company_Name10,'Flight_Name':Flight_Name10,'Arrival':Arrival10,'Departure':Departure10,'Source':Source10,'Destination':Destination10,'Duration':Duration10,'Stops': Stops10,'Meals_Avilablity':Meals10,'Price':Price10}
df11 = pd.DataFrame.from_dict(yt8,orient = 'index')
df11 = df11.transpose()
df11

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=26%2F03%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1597615000397&viewName=normal'
driver.get(url)

# %%
Company_Name11 = []
jt11 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt11:
    j11 =data.text
    Company_Name11.append(j11)
Company_Name11

# %%
Flight_Name11 = []
fn11 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn11:
    f11 = data.text
    Flight_Name11.append(f11)
Flight_Name11

# %%
Arrival11 = []
ar11 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar11:
    a11 = data.text
    Arrival11.append(a11)
Arrival11

# %%
Departure11 = []
dr11 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr11:
    d11 = data.text.split('\n')[2]
    Departure11.append(d11)
Departure11

# %%
Source11 = []
sr11 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr11:
    s11 = data.text.split('\n')[1]
    Source11.append(s11)
Source11

# %%
Destination11 = []
dn11 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn11:
    ds11 = data.text.split('\n')[-1]
    Destination11.append(ds11)
Destination11

# %%
Duration11 = []
dr11 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr11:
    d11 = data.text
    Duration11.append(d11)
Duration11

# %%
Stops11 = []
st11 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st11:
    s11 = data.text.split('\n')[1]
    Stops11.append(s11)
Stops11

# %%
Meals11 = []
ms11 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms11:
    m11 = data.text
    Meals11.append(m11)
Meals11

# %%
Price11 = []
pr11 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr11:
    p11 = data.text
    Price11.append(p11)
Price11

# %%
yt11 = {'Company_Name': Company_Name11,'Flight_Name':Flight_Name11,'Arrival':Arrival11,'Departure':Departure11,'Source':Source11,'Destination':Destination11,'Duration':Duration11,'Stops': Stops11,'Meals_Avilablity':Meals11,'Price':Price11}
df12 = pd.DataFrame.from_dict(yt8,orient = 'index')
df12 = df12.transpose()
df12

# %%
f = pd.concat([df9,df10,df11,df12])
f

# %%
f.to_csv("E:\Data set\Flightprice3.csv")

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=519322347958&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name12 = []
jt12 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt12:
    j12 =data.text
    Company_Name12.append(j12)
Company_Name12
# Out:
# ['IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'Vistara',
#  'Go First',
#  'Air India',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air India',
# ...

# %%
Flight_Name12 = []
fn12 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn12:
    f12 = data.text
    Flight_Name12.append(f12)
Flight_Name12
# Out:
# ['6E-2117',
#  '6E-2792',
#  'SG-8411',
#  'I5-773',
#  '6E-505',
#  'UK-855',
#  'G8-194',
#  'AI-883',
#  'I5-753',
#  '6E-6823/6433',
#  '6E-2005/367',
#  'G8-323/384',
#  'I5-1529/1453',
#  '6E-2282/6809',
#  '6E-153/6954',
#  '6E-2004/793',
#  'G8-338/382',
#  '6E-2774/831',
#  'I5-740/1453',
#  'G8-530/331',
#  '6E-2774/367',
#  'G8-338/371',
#  'G8-354/575',
#  '6E-6939/6954',
#  'G8-392/384',
#  'I5-1732/818',
#  'I5-753/679',
#  'G8-328/575',
#  'G8-422/813',
#  'G8-336/384',
#  'SG-162/4001',
#  'G8-346/575',
#  'G8-530/382',
#  'SG-8157/455',
#  'SG-191/324',
#  'SG-8169/455',
#  'SG-8709/455',
#  'SG-534/324',
#  'SG-162/3736',
#  '6E-2187/309',
#  '6E-2331/831',
#  '6E-2187/6433',
#  'SG-957',
#  'I5-779',
#  'I5-798',
#  '6E-2325/743',
#  '6E-6126/419',
#  'AI-885',
#  'SG-8171',
#  '6E-5161',
#  'SG-3755/3704',
#  'I5-552',
#  '6E-2144',
#  '6E-2138/399',
#  '6E-5318/977',
#  '6E-2519/128',
#  '6E-864/977',
#  '6E-5342/399',
#  'AI-605/685',
#  'AI-805/685',
# ...

# %%
Arrival12 = []
ar12 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar12:
    a12 = data.text
    Arrival12.append(a12)
Arrival12
# Out:
# ['16:15',
#  '19:00',
#  '19:55',
#  '20:00',
#  '21:45',
#  '18:40',
#  '20:30',
#  '22:00',
#  '13:00',
#  '18:00',
#  '09:55',
#  '18:40',
#  '09:35',
#  '12:45',
#  '19:35',
#  '12:15',
#  '10:55',
#  '07:55',
#  '08:10',
#  '06:00',
#  '07:55',
#  '10:55',
#  '22:45',
#  '17:20',
#  '15:45',
#  '21:40',
#  '13:00',
#  '20:50',
#  '20:55',
#  '14:00',
#  '21:55',
#  '19:50',
#  '06:00',
#  '06:20',
#  '06:05',
#  '19:45',
#  '18:55',
#  '21:25',
#  '21:55',
#  '15:00',
#  '06:40',
#  '15:00',
#  '14:55',
#  '05:10',
#  '12:40',
#  '01:50',
#  '11:15',
#  '10:45',
#  '11:55',
#  '12:15',
#  '17:35',
#  '10:40',
#  '10:00',
#  '11:55',
#  '17:00',
#  '23:35',
#  '16:15',
#  '10:45',
#  '21:15',
#  '20:00',
#  '19:00',
#  '21:15',
#  '20:00',
#  '19:00',
#  '18:10',
#  '05:45',
#  '11:00',
#  '21:15',
#  '20:00',
#  '19:00',
#  '02:25',
#  '09:35',
#  '08:10',
#  '09:35',
#  '08:10',
#  '14:00',
#  '14:00',
#  '08:20',
#  '06:55',
#  '14:00',
#  '15:05',
#  '18:45',
#  '19:45',
# ...

# %%
Departure12 = []
dr12 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr12:
    d12 = data.text.split('\n')[2]
    Departure12.append(d12)
Departure12
# Out:
# ['18:40',
#  '21:30',
#  '22:30',
#  '22:35',
#  '00:20',
#  '21:20',
#  '23:10',
#  '00:40',
#  '17:15',
#  '22:35',
#  '14:45',
#  '23:35',
#  '14:45',
#  '18:00',
#  '00:50',
#  '17:35',
#  '16:40',
#  '14:00',
#  '14:45',
#  '12:45',
#  '14:45',
#  '17:55',
#  '06:10',
#  '00:50',
#  '23:35',
#  '05:55',
#  '22:00',
#  '06:10',
#  '06:15',
#  '23:35',
#  '07:45',
#  '06:10',
#  '16:40',
#  '17:05',
#  '20:35',
#  '17:05',
#  '17:05',
#  '20:35',
#  '21:45',
#  '21:30',
#  '14:00',
#  '22:35',
#  '17:40',
#  '07:50',
#  '15:25',
#  '06:50',
#  '16:40',
#  '13:35',
#  '14:25',
#  '14:50',
#  '18:35',
#  '13:20',
#  '12:30',
#  '18:10',
#  '23:20',
#  '06:15',
#  '23:20',
#  '18:10',
#  '06:20',
#  '06:20',
#  '06:20',
#  '22:20',
#  '22:20',
#  '22:20',
#  '23:20',
#  '18:35',
#  '13:25',
#  '14:35',
#  '14:35',
#  '14:35',
#  '07:45',
#  '18:00',
#  '18:00',
#  '19:25',
#  '19:25',
#  '22:20',
#  '06:20',
#  '14:10',
#  '14:10',
#  '14:35',
#  '22:20',
#  '05:55',
#  '12:55',
# ...

# %%
Source12 = []
sr12 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr12:
    s12 = data.text.split('\n')[1]
    Source12.append(s12)
Source12
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
Destination12 = []
dn12 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn12:
    ds12 = data.text.split('\n')[-1]
    Destination12.append(ds12)
Destination12
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
# ...

# %%
Duration12 = []
dr12 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr12:
    d12 = data.text
    Duration12.append(d12)
Duration12
# Out:
# ['2h 25m',
#  '2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 40m',
#  '4h 15m',
#  '4h 35m',
#  '4h 50m',
#  '4h 55m',
#  '5h 10m',
#  '5h 15m',
#  '5h 15m',
#  '5h 20m',
#  '5h 45m',
#  '6h 05m',
#  '6h 35m',
#  '6h 45m',
#  '6h 50m',
#  '7h 00m',
#  '7h 25m',
#  '7h 30m',
#  '7h 50m',
#  '8h 15m',
#  '9h 00m',
#  '9h 20m',
#  '9h 20m',
#  '9h 35m',
#  '9h 50m',
#  '10h 20m',
#  '10h 40m',
#  '10h 45m',
#  '14h 30m',
#  '21h 20m',
#  '22h 10m',
#  '23h 10m',
#  '23h 50m',
#  '6h 30m',
#  '7h 20m',
#  '7h 35m',
#  '2h 45m',
#  '2h 40m',
#  '2h 45m',
#  '5h 00m',
#  '5h 25m',
#  '2h 50m',
#  '2h 30m',
#  '2h 35m',
#  '25h 00m',
#  '2h 40m',
#  '2h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 40m',
#  '7h 05m',
#  '7h 25m',
#  '9h 05m',
#  '10h 20m',
#  '11h 20m',
#  '25h 05m',
#  '26h 20m',
#  '27h 20m',
#  '5h 10m',
#  '12h 50m',
#  '2h 25m',
#  '17h 20m',
#  '18h 35m',
#  '19h 35m',
#  '5h 20m',
#  '8h 25m',
#  '9h 50m',
#  '9h 50m',
#  '11h 15m',
# ...

# %%
Stops12 = []
st12 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st12:
    s12 = data.text.split('\n')[1]
    Stops12.append(s12)
Stops12
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
Meals12 = []
ms12 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms12:
    m12 = data.text
    Meals12.append(m12)
Meals12
# Out:
# ['Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
# ...

# %%
Price12 = []
pr12 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr12:
    p12 = data.text
    Price12.append(p12)
Price12
# Out:
# ['8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,769',
#  '8,769',
#  '8,769',
#  '8,790',
#  '8,896',
#  '8,896',
#  '9,378',
#  '9,987',
#  '10,050',
#  '10,260',
#  '10,313',
#  '10,421',
#  '11,626',
#  '11,888',
#  '11,940',
#  '11,940',
#  '11,940',
#  '11,940',
#  '11,940',
#  '12,045',
#  '12,045',
#  '12,045',
#  '12,045',
#  '12,045',
#  '12,045',
#  '12,203',
#  '12,205',
#  '12,308',
#  '12,360',
#  '12,360',
#  '12,360',
#  '12,780',
#  '12,807',
#  '12,807',
#  '12,807',
#  '12,807',
#  '12,885',
#  '12,885',
#  '13,200',
#  '13,200',
#  '13,200',
# ...

# %%
yt12 = {'Company_Name': Company_Name12,'Flight_Name':Flight_Name12,'Arrival':Arrival12,'Departure':Departure12,'Source':Source12,'Destination':Destination12,'Duration':Duration12,'Stops': Stops12,'Meals_Avilablity':Meals12,'Price':Price12}
df13 = pd.DataFrame.from_dict(yt12,orient = 'index')
df13 = df13.transpose()
df13
# Out:
#     Company_Name Flight_Name Arrival Departure     Source Destination  \
# 0         IndiGo     6E-2117   16:15     18:40  New Delhi         Goa
# 1         IndiGo     6E-2792   19:00     21:30  New Delhi         Goa
# 2       SpiceJet     SG-8411   19:55     22:30  New Delhi         Goa
# 3       Air Asia      I5-773   20:00     22:35  New Delhi         Goa
# 4         IndiGo      6E-505   21:45     00:20  New Delhi         Goa
# ..           ...         ...     ...       ...        ...         ...
# 174         None        None    None      None       None        None
# 175         None        None    None      None       None        None
# 176         None        None    None      None       None        None
# 177         None        None    None      None       None        None
# 178         None        None    None      None       None        None
#
#     Duration     Stops Meals_Avilablity  Price
# 0     2h 25m  Non Stop        Paid Meal  8,160
# ...

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=GOI&originCountry=IN&type=O&unique=708957933189&version=1.2&viewName=normal'
driver.get(url)

# %%
Company_Name13 = []
jt13 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt13:
    j13 =data.text
    Company_Name13.append(j13)
Company_Name13
# Out:
# ['IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'Vistara',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
Flight_Name13 = []
fn13 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn13:
    f13 = data.text
    Flight_Name13.append(f13)
Flight_Name13
# Out:
# ['6E-6955/158',
#  'I5-5002',
#  '6E-2336',
#  '6E-6811/2089',
#  '6E-617/5006',
#  'UK-856',
#  'SG-8412',
#  '6E-468/6684',
#  '6E-418/649',
#  '6E-468/2324',
#  '6E-117/2011',
#  'I5-330',
#  '6E-637/2135',
#  'SG-8172',
#  'I5-776',
#  '6E-637/2106',
#  '6E-5162',
#  '6E-2332',
#  'AI-886',
#  '6E-2119',
#  'I5-1455/749',
#  'UK-848',
#  '6E-117/2773',
#  'I5-1455/1731',
#  '6E-712/2279',
#  'AI-884',
#  'SG-958',
#  '6E-6955/6288',
#  'AI-697/864',
#  'AI-697/806',
#  'AI-697/635',
#  'AI-697/866',
#  'AI-697/809',
#  'AI-697/677',
#  'AI-697/687',
#  'AI-697/442',
#  'AI-697/660',
#  'SG-454/8158',
#  'SG-454/8710',
#  'SG-454/8152',
#  'SG-454/8702',
#  'UK-842/910',
#  'UK-842/996',
#  'UK-842/940',
#  'UK-842/988',
#  'UK-842/950',
#  'UK-842/986',
#  'UK-842/954',
#  'UK-842/970',
#  'UK-842/960',
#  'UK-842/952',
#  'UK-842/944',
#  'I5-774',
#  'SG-325/136',
#  'SG-325/535',
#  '6E-6532',
#  'SG-3735/160',
#  'UK-842/902',
#  'UK-842/928',
#  '6E-6097/2012',
# ...

# %%
Arrival13 = []
ar13 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar13:
    a13 = data.text
    Arrival13.append(a13)
Arrival13
# Out:
# ['01:20',
#  '12:00',
#  '22:00',
#  '18:30',
#  '01:35',
#  '21:55',
#  '23:00',
#  '18:10',
#  '17:15',
#  '18:10',
#  '02:05',
#  '17:45',
#  '15:15',
#  '15:05',
#  '13:50',
#  '15:15',
#  '15:25',
#  '13:55',
#  '14:15',
#  '19:15',
#  '15:15',
#  '14:25',
#  '02:05',
#  '15:15',
#  '14:45',
#  '01:15',
#  '18:10',
#  '01:20',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '23:10',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '13:20',
#  '23:05',
#  '21:05',
#  '21:05',
#  '00:50',
#  '22:05',
#  '13:20',
#  '13:20',
#  '13:10',
#  '16:30',
#  '06:45',
#  '13:10',
#  '16:30',
#  '06:45',
#  '13:10',
#  '15:15',
#  '06:50',
#  '15:15',
#  '06:50',
#  '06:50',
#  '06:50',
#  '06:50',
#  '06:50',
#  '17:35',
#  '17:35',
#  '17:35',
#  '01:40',
#  '18:30',
#  '06:50',
#  '13:20',
#  '18:30',
#  '14:30',
# ...

# %%
Departure13 = []
dr13 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr13:
    d13 = data.text.split('\n')[2]
    Departure13.append(d13)
Departure13
# Out:
# ['05:50',
#  '14:25',
#  '00:35',
#  '00:25',
#  '09:20',
#  '00:40',
#  '01:25',
#  '23:30',
#  '23:20',
#  '00:45',
#  '09:15',
#  '21:45',
#  '20:00',
#  '17:45',
#  '16:30',
#  '22:20',
#  '18:00',
#  '16:35',
#  '16:45',
#  '22:00',
#  '01:05',
#  '17:05',
#  '07:15',
#  '21:10',
#  '21:15',
#  '03:55',
#  '21:00',
#  '07:40',
#  '09:05',
#  '10:15',
#  '11:10',
#  '11:20',
#  '12:20',
#  '15:15',
#  '18:20',
#  '19:10',
#  '20:10',
#  '21:55',
#  '00:05',
#  '09:35',
#  '12:30',
#  '19:45',
#  '20:40',
#  '21:55',
#  '23:00',
#  '00:10',
#  '00:55',
#  '08:05',
#  '11:00',
#  '14:05',
#  '14:30',
#  '16:55',
#  '01:50',
#  '08:35',
#  '23:45',
#  '03:25',
#  '08:40',
#  '18:05',
#  '08:35',
#  '18:10',
#  '21:40',
#  '12:20',
#  '19:25',
#  '22:55',
#  '14:10',
#  '20:45',
#  '20:10',
#  '12:20',
#  '21:15',
#  '15:15',
#  '18:20',
#  '19:10',
#  '20:10',
#  '21:15',
#  '00:05',
#  '09:35',
#  '12:30',
#  '06:55',
#  '01:05',
#  '11:20',
#  '09:40',
#  '01:10',
#  '20:00',
# ...

# %%
Source13 = []
sr13 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr13:
    s13 = data.text.split('\n')[1]
    Source13.append(s13)
Source13
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa']

# %%
Destination13 = []
dn13 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn13:
    ds13 = data.text.split('\n')[-1]
    Destination13.append(ds13)
Destination13
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
Duration13 = []
dr13 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr13:
    d13 = data.text
    Duration13.append(d13)
Duration13
# Out:
# ['4h 30m',
#  '2h 25m',
#  '2h 35m',
#  '5h 55m',
#  '7h 45m',
#  '2h 45m',
#  '2h 25m',
#  '5h 20m',
#  '6h 05m',
#  '6h 35m',
#  '7h 10m',
#  '4h 00m',
#  '4h 45m',
#  '2h 40m',
#  '2h 40m',
#  '7h 05m',
#  '2h 35m',
#  '2h 40m',
#  '2h 30m',
#  '2h 45m',
#  '9h 50m',
#  '2h 40m',
#  '5h 10m',
#  '5h 55m',
#  '6h 30m',
#  '2h 40m',
#  '2h 50m',
#  '6h 20m',
#  '9h 55m',
#  '11h 05m',
#  '12h 00m',
#  '12h 10m',
#  '13h 10m',
#  '16h 05m',
#  '19h 10m',
#  '20h 00m',
#  '21h 00m',
#  '8h 25m',
#  '10h 35m',
#  '20h 05m',
#  '23h 00m',
#  '6h 25m',
#  '7h 20m',
#  '8h 35m',
#  '9h 40m',
#  '10h 50m',
#  '11h 35m',
#  '18h 45m',
#  '21h 40m',
#  '24h 45m',
#  '25h 10m',
#  '27h 35m',
#  '2h 45m',
#  '11h 30m',
#  '26h 40m',
#  '2h 35m',
#  '10h 35m',
#  '4h 45m',
#  '19h 15m',
#  '5h 00m',
#  '5h 10m',
#  '5h 35m',
#  '6h 15m',
#  '6h 25m',
#  '7h 25m',
#  '7h 35m',
#  '4h 55m',
#  '5h 30m',
#  '6h 00m',
#  '8h 25m',
#  '11h 30m',
#  '12h 20m',
#  '13h 20m',
#  '14h 25m',
# ...

# %%
Stops13 = []
st13 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st13:
    s13 = data.text.split('\n')[1]
    Stops13.append(s13)
Stops13
# Out:
# ['1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
# ...

# %%
Meals13 = []
ms13 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms13:
    m13 = data.text
    Meals13.append(m13)
Meals13
# Out:
# ['Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
# ...

# %%
Price13 = []
pr13 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr13:
    p13 = data.text
    Price13.append(p13)
Price13
# Out:
# ['8,970',
#  '9,621',
#  '9,674',
#  '10,188',
#  '10,188',
#  '10,252',
#  '10,461',
#  '10,797',
#  '10,797',
#  '10,797',
#  '10,797',
#  '10,987',
#  '11,406',
#  '11,721',
#  '11,827',
#  '12,015',
#  '12,089',
#  '12,089',
#  '12,352',
#  '13,139',
#  '13,369',
#  '13,507',
#  '13,842',
#  '14,610',
#  '15,060',
#  '15,082',
#  '15,501',
#  '15,669',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,712',
#  '15,996',
#  '15,996',
#  '15,996',
#  '15,996',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,080',
#  '16,237',
#  '16,354',
#  '16,354',
#  '16,445',
#  '16,446',
#  '16,605',
#  '16,605',
#  '16,656',
#  '16,656',
#  '16,656',
#  '16,656',
#  '16,656',
#  '16,656',
#  '16,656',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,762',
#  '16,836',
#  '16,836',
#  '16,836',
# ...

# %%
yt13 = {'Company_Name': Company_Name13,'Flight_Name':Flight_Name13,'Arrival':Arrival13,'Departure':Departure13,'Source':Source13,'Destination':Destination13,'Duration':Duration13,'Stops': Stops13,'Meals_Avilablity':Meals13,'Price':Price13}
df14 = pd.DataFrame.from_dict(yt13,orient = 'index')
df14 = df14.transpose()
df14
# Out:
#     Company_Name   Flight_Name Arrival Departure Source Destination Duration  \
# 0         IndiGo   6E-6955/158   01:20     05:50    Goa   New Delhi   4h 30m
# 1       Air Asia       I5-5002   12:00     14:25    Goa   New Delhi   2h 25m
# 2         IndiGo       6E-2336   22:00     00:35    Goa   New Delhi   2h 35m
# 3         IndiGo  6E-6811/2089   18:30     00:25    Goa   New Delhi   5h 55m
# 4         IndiGo   6E-617/5006   01:35     09:20    Goa   New Delhi   7h 45m
# ..           ...           ...     ...       ...    ...         ...      ...
# 103         None          None    None      None   None        None     None
# 104         None          None    None      None   None        None     None
# 105         None          None    None      None   None        None     None
# 106         None          None    None      None   None        None     None
# 107         None          None    None      None   None        None     None
#
#         Stops Meals_Avilablity   Price
# ...

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1025777709785&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name14 = []
jt14 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt14:
    j14 =data.text
    Company_Name14.append(j14)
Company_Name14
# Out:
# ['IndiGo',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Vistara',
#  'SpiceJet',
#  'Air India',
#  'Vistara',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
# ...

# %%
Flight_Name14 = []
fn14 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn14:
    f14 = data.text
    Flight_Name14.append(f14)
Flight_Name14
# Out:
# ['6E-353',
#  '6E-788',
#  'G8-101',
#  'UK-747',
#  '6E-6557',
#  '6E-2082',
#  'UK-707',
#  '6E-912',
#  '6E-2057',
#  '6E-2517',
#  '6E-6005',
#  'I5-548',
#  'UK-737',
#  'SG-8251',
#  'AI-762',
#  'UK-727',
#  'G8-105',
#  'SG-8254',
#  '6E-6198/7235',
#  '6E-2282/6469',
#  'G8-151/3178',
#  'G8-392/520',
#  'G8-354/511',
#  'G8-171/394',
#  'G8-336/520',
#  'G8-2513/394',
#  'G8-328/511',
#  'G8-119/790',
#  'SG-8263',
#  'G8-422/3125',
#  '6E-2485/736',
#  '6E-2481/736',
#  '6E-5126/736',
#  '6E-2107/6469',
#  'I5-1529/592',
#  'I5-740/592',
#  'I5-1529/992',
#  'AI-764',
#  '6E-307/104',
#  'UK-705',
#  'I5-1732/611',
#  '6E-204/801',
#  '6E-204/7205',
#  '6E-282',
#  '6E-7403/6568',
#  '6E-2334/7306',
#  '6E-2018/6175',
#  '6E-6187/7205',
#  '6E-2093/7116',
#  'G8-713/532',
#  '6E-2095/507',
#  'I5-747/992',
#  'AI-504/772',
#  'AI-803/772',
#  '6E-2513',
#  'G8-2501/511',
#  'UK-993/773',
#  'UK-945/773',
#  'AI-605/675',
#  'AI-805/675',
#  'AI-624/675',
#  'UK-941/771',
# ...

# %%
Arrival14 = []
ar14 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar14:
    a14 = data.text
    Arrival14.append(a14)
Arrival14
# Out:
# ['06:05',
#  '03:00',
#  '05:45',
#  '06:15',
#  '12:25',
#  '15:20',
#  '17:30',
#  '17:35',
#  '18:40',
#  '20:00',
#  '22:10',
#  '04:55',
#  '15:55',
#  '18:15',
#  '20:15',
#  '20:30',
#  '21:25',
#  '19:30',
#  '16:20',
#  '12:45',
#  '12:20',
#  '15:45',
#  '22:45',
#  '18:20',
#  '14:00',
#  '16:45',
#  '20:50',
#  '20:30',
#  '07:05',
#  '20:55',
#  '13:25',
#  '12:25',
#  '09:20',
#  '08:10',
#  '09:35',
#  '08:10',
#  '09:35',
#  '16:45',
#  '05:30',
#  '07:30',
#  '21:40',
#  '11:55',
#  '11:55',
#  '09:55',
#  '07:20',
#  '07:55',
#  '07:30',
#  '15:15',
#  '10:15',
#  '20:05',
#  '15:10',
#  '18:45',
#  '21:15',
#  '06:10',
#  '08:40',
#  '02:40',
#  '12:50',
#  '11:40',
#  '21:15',
#  '20:00',
#  '19:00',
#  '16:45',
#  '15:30',
#  '12:50',
#  '09:45',
#  '11:40',
#  '16:45',
#  '13:00',
#  '09:35',
#  '08:10',
#  '14:00',
#  '17:50',
#  '14:20',
#  '21:55',
#  '20:40',
#  '14:00',
#  '19:50',
#  '18:45',
#  '10:20',
#  '09:30',
#  '08:50',
#  '06:30',
#  '06:30',
# ...

# %%
Departure14 = []
dr14 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr14:
    d14 = data.text.split('\n')[2]
    Departure14.append(d14)
Departure14
# Out:
# ['07:50',
#  '05:05',
#  '07:50',
#  '08:20',
#  '14:30',
#  '17:25',
#  '19:35',
#  '19:40',
#  '20:45',
#  '22:05',
#  '00:15',
#  '07:05',
#  '18:05',
#  '20:25',
#  '22:25',
#  '22:45',
#  '23:40',
#  '21:55',
#  '21:35',
#  '18:15',
#  '17:55',
#  '00:30',
#  '08:30',
#  '04:20',
#  '00:30',
#  '04:20',
#  '08:30',
#  '08:30',
#  '09:05',
#  '07:45',
#  '17:30',
#  '17:30',
#  '17:30',
#  '18:15',
#  '20:25',
#  '20:25',
#  '02:05',
#  '19:10',
#  '11:25',
#  '09:35',
#  '11:15',
#  '18:30',
#  '22:40',
#  '12:00',
#  '12:30',
#  '18:50',
#  '13:25',
#  '22:40',
#  '19:25',
#  '08:35',
#  '22:20',
#  '02:05',
#  '07:45',
#  '07:45',
#  '10:45',
#  '08:30',
#  '19:55',
#  '19:55',
#  '08:50',
#  '08:50',
#  '08:50',
#  '09:40',
#  '09:40',
#  '09:40',
#  '07:45',
#  '09:40',
#  '16:55',
#  '20:10',
#  '18:05',
#  '18:05',
#  '18:50',
#  '08:50',
#  '19:55',
#  '09:40',
#  '09:40',
#  '08:50',
#  '04:20',
#  '11:15',
#  '16:55',
#  '16:55',
#  '16:55',
#  '13:10',
#  '18:30',
# ...

# %%
Source14 = []
sr14 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr14:
    s14 = data.text.split('\n')[1]
    Source14.append(s14)
Source14
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
Destination14 = []
dn14 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn14:
    ds14 = data.text.split('\n')[-1]
    Destination14.append(ds14)
Destination14
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
Duration14 = []
dr14 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr14:
    d14 = data.text
    Duration14.append(d14)
Duration14
# Out:
# ['1h 45m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 25m',
#  '5h 15m',
#  '5h 30m',
#  '5h 35m',
#  '8h 45m',
#  '9h 45m',
#  '10h 00m',
#  '10h 30m',
#  '11h 35m',
#  '11h 40m',
#  '12h 00m',
#  '2h 00m',
#  '10h 50m',
#  '4h 05m',
#  '5h 05m',
#  '8h 10m',
#  '10h 05m',
#  '10h 50m',
#  '12h 15m',
#  '16h 30m',
#  '2h 25m',
#  '5h 55m',
#  '2h 05m',
#  '13h 35m',
#  '6h 35m',
#  '10h 45m',
#  '2h 05m',
#  '5h 10m',
#  '10h 55m',
#  '5h 55m',
#  '7h 25m',
#  '9h 10m',
#  '12h 30m',
#  '7h 10m',
#  '7h 20m',
#  '10h 30m',
#  '25h 35m',
#  '2h 05m',
#  '5h 50m',
#  '7h 05m',
#  '8h 15m',
#  '11h 35m',
#  '12h 50m',
#  '13h 50m',
#  '16h 55m',
#  '18h 10m',
#  '20h 50m',
#  '22h 00m',
#  '22h 00m',
#  '24h 10m',
#  '7h 10m',
#  '8h 30m',
#  '9h 55m',
#  '4h 50m',
#  '15h 00m',
#  '5h 35m',
#  '11h 45m',
# ...

# %%
Stops14 = []
st14 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st14:
    s14 = data.text.split('\n')[1]
    Stops14.append(s14)
Stops14
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
# ...

# %%
Meals14 = []
ms14 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms14:
    m14 = data.text
    Meals14.append(m14)
Meals14
# Out:
# ['Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
# ...

# %%
Price14 = []
pr14 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr14:
    p14 = data.text
    Price14.append(p14)
Price14
# Out:
# ['7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,320',
#  '7,740',
#  '7,827',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,160',
#  '8,370',
#  '8,370',
#  '8,370',
#  '8,580',
#  '8,580',
#  '9,420',
#  '9,515',
#  '10,260',
#  '10,260',
#  '11,100',
#  '11,100',
#  '11,100',
#  '11,940',
#  '11,940',
#  '11,940',
#  '13,069',
#  '13,148',
#  '13,200',
#  '14,040',
#  '14,040',
#  '14,460',
#  '14,954',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,090',
#  '15,143',
#  '15,294',
#  '15,294',
#  '15,510',
#  '15,510',
#  '15,615',
#  '15,615',
#  '15,615',
#  '15,930',
#  '16,035',
#  '16,113',
#  '16,140',
#  '16,140',
# ...

# %%
yt14 = {'Company_Name': Company_Name14,'Flight_Name':Flight_Name14,'Arrival':Arrival14,'Departure':Departure14,'Source':Source14,'Destination':Destination14,'Duration':Duration14,'Stops': Stops14,'Meals_Avilablity':Meals14,'Price':Price14}
df15 = pd.DataFrame.from_dict(yt14,orient = 'index')
df15 = df15.transpose()
df15
# Out:
#     Company_Name Flight_Name Arrival Departure     Source Destination  \
# 0         IndiGo      6E-353   06:05     07:50  New Delhi     Kolkata
# 1         IndiGo      6E-788   03:00     05:05  New Delhi     Kolkata
# 2       Go First      G8-101   05:45     07:50  New Delhi     Kolkata
# 3        Vistara      UK-747   06:15     08:20  New Delhi     Kolkata
# 4         IndiGo     6E-6557   12:25     14:30  New Delhi     Kolkata
# ..           ...         ...     ...       ...        ...         ...
# 171         None        None    None      None       None        None
# 172         None        None    None      None       None        None
# 173         None        None    None      None       None        None
# 174         None        None    None      None       None        None
# 175         None        None    None      None       None        None
#
#     Duration     Stops Meals_Avilablity  Price
# 0     1h 45m  Non Stop        Paid Meal  7,320
# ...

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=237498959792&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name15 = []
jt15 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt15:
    j15 =data.text
    Company_Name15.append(j15)
Company_Name15
# Out:
# ['Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
# ...

# %%
Flight_Name15 = []
fn15 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn15:
    f15 = data.text
    Flight_Name15.append(f15)
Flight_Name15
# Out:
# ['I5-1562',
#  '6E-503',
#  'I5-592',
#  '6E-172',
#  '6E-217',
#  'G8-790',
#  'SG-538',
#  'G8-791',
#  '6E-975',
#  '6E-6572',
#  'I5-992',
#  'I5-611',
#  '6E-6366/6038',
#  '6E-841/6275',
#  '6E-978/7205',
#  '6E-541/292',
#  'I5-722/548',
#  'G8-320/520',
#  'I5-1576/517',
#  '6E-841/923',
#  'I5-1562/320',
#  '6E-6825/292',
#  '6E-541/986',
#  'I5-749/548',
#  '6E-6269/292',
#  '6E-6825/986',
#  'G8-241/394',
#  'G8-399/511',
#  'I5-1567/1562',
#  'G8-118/101',
#  'G8-320/511',
#  'SG-3027/388',
#  'G8-803/532',
#  'G8-395/520',
#  'AI-772',
#  '6E-368/157',
#  '6E-6212/292',
#  '6E-6212/986',
#  '6E-6212/6275',
#  '6E-255/736',
#  '6E-457/7179',
#  'I5-1731/548',
#  '6E-968/507',
#  '6E-442',
#  '6E-227',
#  '6E-484/376',
#  '6E-6067/944',
#  '6E-684/6494',
#  '6E-6257/376',
#  '6E-855/6494',
#  '6E-6491/283',
#  '6E-6491/944',
#  '6E-537/6907',
#  '6E-537/283',
#  'UK-858/775',
#  'UK-866/771',
#  'UK-858/773',
#  'UK-850/771',
#  'UK-864/771',
#  'UK-854/771',
# ...

# %%
Arrival15 = []
ar15 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar15:
    a15 = data.text
    Arrival15.append(a15)
Arrival15
# Out:
# ['14:20',
#  '12:10',
#  '18:15',
#  '13:40',
#  '18:10',
#  '06:00',
#  '17:05',
#  '19:50',
#  '22:05',
#  '15:25',
#  '23:30',
#  '08:10',
#  '12:35',
#  '14:50',
#  '16:10',
#  '09:25',
#  '00:25',
#  '17:45',
#  '07:35',
#  '14:50',
#  '14:20',
#  '08:05',
#  '09:25',
#  '22:30',
#  '07:00',
#  '08:05',
#  '17:35',
#  '21:30',
#  '06:50',
#  '20:30',
#  '17:45',
#  '05:45',
#  '17:15',
#  '08:15',
#  '05:20',
#  '05:15',
#  '11:10',
#  '11:10',
#  '11:10',
#  '08:35',
#  '08:20',
#  '17:55',
#  '16:50',
#  '09:15',
#  '06:30',
#  '07:10',
#  '15:30',
#  '21:45',
#  '05:15',
#  '20:10',
#  '12:35',
#  '12:35',
#  '10:15',
#  '10:15',
#  '06:40',
#  '21:40',
#  '06:40',
#  '19:55',
#  '19:00',
#  '18:25',
#  '21:40',
#  '19:55',
#  '19:00',
#  '21:40',
#  '18:25',
#  '19:55',
#  '19:00',
#  '18:25',
#  '06:40',
#  '08:55',
#  '07:00',
#  '21:10',
#  '21:10',
#  '07:00',
#  '19:40',
#  '18:50',
#  '19:40',
#  '17:45',
#  '18:50',
#  '07:00',
#  '17:45',
#  '21:10',
#  '19:40',
# ...

# %%
Departure15 = []
dr15 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr15:
    d15 = data.text.split('\n')[2]
    Departure15.append(d15)
Departure15
# Out:
# ['18:05',
#  '14:20',
#  '20:25',
#  '16:05',
#  '20:35',
#  '08:30',
#  '19:35',
#  '22:20',
#  '00:35',
#  '18:00',
#  '02:05',
#  '11:15',
#  '17:00',
#  '19:45',
#  '22:40',
#  '16:00',
#  '07:05',
#  '00:30',
#  '14:35',
#  '21:50',
#  '22:00',
#  '16:00',
#  '17:30',
#  '07:05',
#  '16:00',
#  '17:30',
#  '04:20',
#  '08:30',
#  '18:05',
#  '07:50',
#  '08:30',
#  '20:50',
#  '08:35',
#  '00:30',
#  '07:45',
#  '13:25',
#  '16:00',
#  '17:30',
#  '19:45',
#  '17:30',
#  '15:55',
#  '07:05',
#  '22:20',
#  '11:50',
#  '09:05',
#  '13:20',
#  '22:30',
#  '05:15',
#  '13:20',
#  '05:15',
#  '19:15',
#  '22:30',
#  '17:15',
#  '19:15',
#  '16:55',
#  '09:40',
#  '19:55',
#  '09:40',
#  '09:40',
#  '09:40',
#  '16:55',
#  '16:55',
#  '16:55',
#  '19:55',
#  '16:55',
#  '19:55',
#  '19:55',
#  '19:55',
#  '09:40',
#  '17:15',
#  '18:05',
#  '08:20',
#  '09:35',
#  '19:35',
#  '08:20',
#  '08:20',
#  '09:35',
#  '08:20',
#  '09:35',
#  '22:45',
#  '09:35',
#  '18:05',
#  '18:05',
# ...

# %%
Source15 = []
sr15 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr15:
    s15 = data.text.split('\n')[1]
    Source15.append(s15)
Source15
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
Destination15 = []
dn15 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn15:
    ds15 = data.text.split('\n')[-1]
    Destination15.append(ds15)
Destination15
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
Duration15 = []
dr15 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr15:
    d15 = data.text
    Duration15.append(d15)
Duration15
# Out:
# ['3h 45m',
#  '2h 10m',
#  '2h 10m',
#  '2h 25m',
#  '2h 25m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '3h 05m',
#  '4h 25m',
#  '4h 55m',
#  '6h 30m',
#  '6h 35m',
#  '6h 40m',
#  '6h 45m',
#  '7h 00m',
#  '7h 00m',
#  '7h 40m',
#  '7h 55m',
#  '8h 05m',
#  '8h 35m',
#  '9h 00m',
#  '9h 25m',
#  '10h 45m',
#  '11h 00m',
#  '11h 15m',
#  '11h 20m',
#  '14h 45m',
#  '15h 05m',
#  '15h 20m',
#  '16h 15m',
#  '2h 25m',
#  '8h 10m',
#  '4h 50m',
#  '6h 20m',
#  '8h 35m',
#  '8h 55m',
#  '7h 35m',
#  '13h 10m',
#  '5h 30m',
#  '2h 35m',
#  '2h 35m',
#  '6h 10m',
#  '7h 00m',
#  '7h 30m',
#  '8h 05m',
#  '9h 05m',
#  '6h 40m',
#  '9h 55m',
#  '7h 00m',
#  '9h 00m',
#  '10h 15m',
#  '12h 00m',
#  '13h 15m',
#  '13h 45m',
#  '14h 40m',
#  '15h 15m',
#  '19h 15m',
#  '21h 00m',
#  '21h 55m',
#  '22h 15m',
#  '22h 30m',
#  '24h 00m',
#  '24h 55m',
#  '25h 30m',
#  '27h 00m',
#  '8h 20m',
#  '11h 05m',
#  '11h 10m',
#  '12h 25m',
#  '12h 35m',
# ...

# %%
Stops15 = []
st15 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st15:
    s15 = data.text.split('\n')[1]
    Stops15.append(s15)
Stops15
# Out:
# ['1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
Meals15 = []
ms15 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms15:
    m15 = data.text
    Meals15.append(m15)
Meals15
# Out:
# ['Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
# ...

# %%
Price15 = []
pr15 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr15:
    p15 = data.text
    Price15.append(p15)
Price15
# Out:
# ['6,096',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,333',
#  '6,334',
#  '6,732',
#  '7,131',
#  '7,131',
#  '7,131',
#  '7,131',
#  '7,929',
#  '8,644',
#  '8,727',
#  '8,929',
#  '9,530',
#  '10,901',
#  '10,901',
#  '10,901',
#  '10,901',
#  '10,901',
#  '11,163',
#  '11,163',
#  '11,373',
#  '11,373',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,097',
#  '12,423',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
#  '12,990',
# ...

# %%
yt15 = {'Company_Name': Company_Name15,'Flight_Name':Flight_Name15,'Arrival':Arrival15,'Departure':Departure15,'Source':Source15,'Destination':Destination15,'Duration':Duration15,'Stops': Stops15,'Meals_Avilablity':Meals15,'Price':Price15}
df16 = pd.DataFrame.from_dict(yt15,orient = 'index')
df16 = df16.transpose()
df16
# Out:
#     Company_Name Flight_Name Arrival Departure     Source Destination  \
# 0       Air Asia     I5-1562   14:20     18:05  Bangalore     Kolkata
# 1         IndiGo      6E-503   12:10     14:20  Bangalore     Kolkata
# 2       Air Asia      I5-592   18:15     20:25  Bangalore     Kolkata
# 3         IndiGo      6E-172   13:40     16:05  Bangalore     Kolkata
# 4         IndiGo      6E-217   18:10     20:35  Bangalore     Kolkata
# ..           ...         ...     ...       ...        ...         ...
# 174         None        None    None      None       None        None
# 175         None        None    None      None       None        None
# 176         None        None    None      None       None        None
# 177         None        None    None      None       None        None
# 178         None        None    None      None       None        None
#
#     Duration     Stops Meals_Avilablity  Price
# 0     3h 45m    1 Stop        Paid Meal  6,096
# ...

# %%
url = 'https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=28%2F03%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=871923176022&version=1.1&viewName=normal'
driver.get(url)

# %%
Company_Name16 = []
jt16 = driver.find_elements_by_xpath('//span[@class ="i-b text ellipsis"]')
for data in jt16:
    j16 =data.text
    Company_Name16.append(j16)
Company_Name16
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'Go First',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
Flight_Name16 = []
fn16 = driver.find_elements_by_xpath('//p[@class ="normal fs-11 font-lightestgrey no-wrap fl-no"]')
for data in fn16:
    f16 = data.text
    Flight_Name16.append(f16)
Flight_Name16
# Out:
# ['6E-429',
#  '6E-5296',
#  '6E-5289',
#  'UK-773',
#  '6E-395',
#  'G8-511',
#  'UK-771',
#  'SG-241',
#  '6E-822',
#  'SG-467',
#  'G8-520',
#  'AI-675',
#  'UK-775',
#  '6E-6086',
#  '6E-6165/7205',
#  '6E-5324/669',
#  '6E-6227/801',
#  '6E-843/6553',
#  'I5-942/592',
#  'G8-330/101',
#  '6E-5232/7235',
#  '6E-542/7117',
#  'I5-338/992',
#  'G8-383/791',
#  'G8-345/101',
#  '6E-6025/6181',
#  'G8-363/532',
#  'SG-8702/8251',
#  '6E-6227/7205',
#  'G8-322/101',
#  'G8-325/790',
#  'G8-341/101',
#  'SG-8710/8263',
#  'I5-330/548',
#  'SG-252/538',
#  'SG-8702/8254',
#  'G8-398/790',
#  'I5-942/992',
#  'SG-8152/8251',
#  'SG-8158/8263',
#  'SG-251/623',
#  'G8-339/101',
#  'SG-8152/8254',
#  'SG-611/388',
#  'SG-8710/8251',
#  'SG-8702/8263',
#  'SG-8710/8254',
#  'AI-774',
#  '6E-6301/736',
#  '6E-5315/6553',
#  '6E-5388/944',
#  '6E-6697/6907',
#  '6E-5314/944',
#  '6E-461/376',
#  '6E-6697/283',
#  '6E-461/6907',
#  '6E-5386/6494',
#  '6E-6697/944',
#  'AI-607/772',
# ...

# %%
Arrival16 = []
ar16 = driver.find_elements_by_xpath('//div[@class ="i-b pr"]')
for data in ar16:
    a16 = data.text
    Arrival16.append(a16)
Arrival16
# Out:
# ['07:50',
#  '09:50',
#  '12:55',
#  '17:20',
#  '17:35',
#  '05:50',
#  '07:00',
#  '06:10',
#  '06:25',
#  '20:50',
#  '21:45',
#  '06:00',
#  '14:05',
#  '19:25',
#  '17:10',
#  '05:20',
#  '12:20',
#  '15:00',
#  '13:05',
#  '00:10',
#  '13:55',
#  '15:45',
#  '18:10',
#  '13:00',
#  '22:30',
#  '21:25',
#  '22:30',
#  '10:15',
#  '12:20',
#  '21:30',
#  '21:45',
#  '20:40',
#  '21:55',
#  '19:45',
#  '08:10',
#  '10:15',
#  '20:00',
#  '13:05',
#  '07:20',
#  '19:35',
#  '19:35',
#  '18:00',
#  '07:20',
#  '05:40',
#  '21:55',
#  '10:15',
#  '21:55',
#  '21:05',
#  '09:10',
#  '10:20',
#  '17:15',
#  '11:10',
#  '16:05',
#  '06:05',
#  '11:10',
#  '06:05',
#  '18:05',
#  '11:10',
#  '16:40',
#  '09:30',
#  '06:10',
#  '19:55',
#  '17:35',
#  '12:25',
#  '12:25',
#  '22:45',
#  '12:25',
#  '21:55',
#  '22:45',
#  '20:55',
#  '21:55',
#  '19:45',
#  '20:55',
#  '19:45',
#  '13:55',
#  '13:15',
#  '11:55',
#  '15:45',
#  '11:55',
#  '05:45',
#  '18:00',
#  '14:35',
#  '12:10',
# ...

# %%
Departure16 = []
dr16 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dr16:
    d16 = data.text.split('\n')[2]
    Departure16.append(d16)
Departure16
# Out:
# ['10:20',
#  '12:25',
#  '15:30',
#  '19:55',
#  '20:10',
#  '08:30',
#  '09:40',
#  '08:55',
#  '09:10',
#  '23:35',
#  '00:30',
#  '08:50',
#  '16:55',
#  '22:20',
#  '22:40',
#  '11:05',
#  '18:30',
#  '21:40',
#  '20:25',
#  '07:50',
#  '21:35',
#  '23:40',
#  '02:05',
#  '22:20',
#  '07:50',
#  '06:50',
#  '08:35',
#  '20:25',
#  '22:40',
#  '07:50',
#  '08:30',
#  '07:50',
#  '09:05',
#  '07:05',
#  '19:35',
#  '21:55',
#  '08:30',
#  '02:05',
#  '20:25',
#  '09:05',
#  '09:15',
#  '07:50',
#  '21:55',
#  '20:50',
#  '20:25',
#  '09:05',
#  '21:55',
#  '23:55',
#  '17:30',
#  '21:40',
#  '22:30',
#  '17:15',
#  '22:30',
#  '13:20',
#  '19:15',
#  '17:15',
#  '05:15',
#  '22:30',
#  '07:45',
#  '07:45',
#  '07:45',
#  '05:15',
#  '22:45',
#  '18:05',
#  '19:35',
#  '08:20',
#  '22:45',
#  '08:20',
#  '09:35',
#  '08:20',
#  '09:35',
#  '08:20',
#  '09:35',
#  '09:35',
#  '19:25',
#  '22:20',
#  '18:05',
#  '22:45',
#  '19:35',
#  '22:25',
#  '23:40',
#  '23:40',
#  '23:40',
# ...

# %%
Source16 = []
sr16 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in sr16:
    s16 = data.text.split('\n')[1]
    Source16.append(s16)
Source16
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
Destination16 = []
dn16 = driver.find_elements_by_xpath('//div[@class ="timing-det bdr-btm v-aligm-t"]')
for data in dn16:
    ds16 = data.text.split('\n')[-1]
    Destination16.append(ds16)
Destination16
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
Duration16 = []
dr16 = driver.find_elements_by_xpath('//p[@class ="fs-12 bold du mb-2"]')
for data in dr16:
    d16 = data.text
    Duration16.append(d16)
Duration16
# Out:
# ['2h 30m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 35m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '5h 30m',
#  '5h 45m',
#  '6h 10m',
#  '6h 40m',
#  '7h 20m',
#  '7h 40m',
#  '7h 40m',
#  '7h 55m',
#  '7h 55m',
#  '9h 20m',
#  '9h 20m',
#  '9h 25m',
#  '10h 05m',
#  '10h 10m',
#  '10h 20m',
#  '10h 20m',
#  '10h 45m',
#  '11h 10m',
#  '11h 10m',
#  '11h 20m',
#  '11h 25m',
#  '11h 40m',
#  '12h 30m',
#  '13h 00m',
#  '13h 05m',
#  '13h 30m',
#  '13h 40m',
#  '13h 50m',
#  '14h 35m',
#  '15h 10m',
#  '22h 30m',
#  '22h 50m',
#  '24h 00m',
#  '2h 50m',
#  '8h 20m',
#  '11h 20m',
#  '5h 15m',
#  '6h 05m',
#  '6h 25m',
#  '7h 15m',
#  '8h 05m',
#  '11h 10m',
#  '11h 10m',
#  '11h 20m',
#  '15h 05m',
#  '22h 15m',
#  '25h 35m',
#  '9h 20m',
#  '5h 10m',
#  '5h 40m',
#  '7h 10m',
#  '9h 35m',
#  '10h 20m',
#  '10h 25m',
#  '10h 50m',
#  '11h 25m',
#  '11h 40m',
#  '12h 35m',
#  '12h 40m',
#  '13h 50m',
# ...

# %%
Stops16 = []
st16 = driver.find_elements_by_xpath('//div[@class ="stop-cont pl-13"]')
for data in st16:
    s16 = data.text.split('\n')[1]
    Stops16.append(s16)
Stops16
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
Meals16 = []
ms16 = driver.find_elements_by_xpath('//span[@class ="meal"]')
for data in ms16:
    m16 = data.text
    Meals16.append(m16)
Meals16
# Out:
# ['Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Free Meal',
#  'Free Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
#  'Paid Meal',
# ...

# %%
Price16 = []
pr16 = driver.find_elements_by_xpath('//div[@class ="i-b tipsy fare-summary-tooltip fs-18"]')
for data in pr16:
    p16 = data.text
    Price16.append(p16)
Price16
# Out:
# ['8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,673',
#  '9,366',
#  '9,975',
#  '10,826',
#  '10,826',
#  '10,826',
#  '10,826',
#  '10,826',
#  '10,826',
#  '10,826',
#  '10,826',
#  '12,138',
#  '12,138',
#  '12,138',
#  '12,191',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,200',
#  '12,411',
#  '13,020',
#  '13,092',
#  '13,092',
#  '13,092',
#  '13,381',
# ...

# %%
yt16 = {'Company_Name': Company_Name16,'Flight_Name':Flight_Name16,'Arrival':Arrival16,'Departure':Departure16,'Source':Source16,'Destination':Destination16,'Duration':Duration16,'Stops': Stops16,'Meals_Avilablity':Meals16,'Price':Price16}
df17 = pd.DataFrame.from_dict(yt16,orient = 'index')
df17 = df17.transpose()
df17
# Out:
#     Company_Name Flight_Name Arrival Departure  Source Destination Duration  \
# 0         IndiGo      6E-429   07:50     10:20  Mumbai     Kolkata   2h 30m
# 1         IndiGo     6E-5296   09:50     12:25  Mumbai     Kolkata   2h 35m
# 2         IndiGo     6E-5289   12:55     15:30  Mumbai     Kolkata   2h 35m
# 3        Vistara      UK-773   17:20     19:55  Mumbai     Kolkata   2h 35m
# 4         IndiGo      6E-395   17:35     20:10  Mumbai     Kolkata   2h 35m
# ..           ...         ...     ...       ...     ...         ...      ...
# 159         None        None    None      None    None        None     None
# 160         None        None    None      None    None        None     None
# 161         None        None    None      None    None        None     None
# 162         None        None    None      None    None        None     None
# 163         None        None    None      None    None        None     None
#
#         Stops Meals_Avilablity  Price
# ...

# %%
p = pd.concat([df13,df14,df15,df16,df17])
p
# Out:
#     Company_Name Flight_Name Arrival Departure     Source Destination  \
# 0         IndiGo     6E-2117   16:15     18:40  New Delhi         Goa
# 1         IndiGo     6E-2792   19:00     21:30  New Delhi         Goa
# 2       SpiceJet     SG-8411   19:55     22:30  New Delhi         Goa
# 3       Air Asia      I5-773   20:00     22:35  New Delhi         Goa
# 4         IndiGo      6E-505   21:45     00:20  New Delhi         Goa
# ..           ...         ...     ...       ...        ...         ...
# 159         None        None    None      None       None        None
# 160         None        None    None      None       None        None
# 161         None        None    None      None       None        None
# 162         None        None    None      None       None        None
# 163         None        None    None      None       None        None
#
#     Duration     Stops Meals_Avilablity  Price
# 0     2h 25m  Non Stop        Paid Meal  8,160
# ...

# %%
p.to_csv("E:\Data set\Flightprice4.csv")
